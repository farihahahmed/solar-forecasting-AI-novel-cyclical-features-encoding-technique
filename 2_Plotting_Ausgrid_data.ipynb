# %% [markdown]
# <a href="https://colab.research.google.com/github/farihahahmed/solar-forecasting-AI-novel-cyclical-features-encoding-technique/blob/main/2_Plotting_Ausgrid_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing data

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Restarting Lumiere - Farihah and Mauricio/df_a.csv')

# %%
df = df.drop("Unnamed: 0", axis=1)

# %% [markdown]
# Visualizing data with plots

# %%
df.head()
# Out:
#    customer_numbers       date  time  PV_power
# 0                 1  1/07/2012  0:30       0.0
# 1                 1  1/07/2012  1:00       0.0
# 2                 1  1/07/2012  1:30       0.0
# 3                 1  1/07/2012  2:00       0.0
# 4                 1  1/07/2012  2:30       0.0

# %%
import matplotlib.pyplot as plt
x_axis = df.time[0:47]
y_axis = df.PV_power[0:47]

plt.figure(figsize=(18,6))
plt.plot(x_axis, y_axis)
plt.xlabel('Time')
plt.ylabel('PV Power')
plt.title('Customer 1, 1/07/2012')
# Out:
# Text(0.5, 1.0, 'Customer 1, 1/07/2012')

# %%
x_axis = df.time[48:95]
y_axis = df.PV_power[48:95]

plt.figure(figsize=(18,6))
plt.plot(x_axis, y_axis)
plt.xlabel('Time')
plt.ylabel('PV Power')
plt.title('Customer 1, 2/07/2012')
# Out:
# Text(0.5, 1.0, 'Customer 1, 2/07/2012')

# %%
x_axis = df.time[96:143]
y_axis = df.PV_power[96:143]

plt.figure(figsize=(18,6))
plt.plot(x_axis, y_axis)
plt.xlabel('Time')
plt.ylabel('PV Power')
plt.title('Customer 1, 3/07/2012')
# Out:
# Text(0.5, 1.0, 'Customer 1, 3/07/2012')

# %%
x_axis = df.time[144:191]
y_axis = df.PV_power[144:191]

plt.figure(figsize=(18,6))
plt.plot(x_axis, y_axis)
plt.xlabel('Time')
plt.ylabel('PV Power')
plt.title('Customer 1, 4/07/2012')
# Out:
# Text(0.5, 1.0, 'Customer 1, 4/07/2012')

# %%
x_axis = df.time[192:239]
y_axis = df.PV_power[192:239]

plt.figure(figsize=(18,6))
plt.plot(x_axis, y_axis)
plt.xlabel('Time')
plt.ylabel('PV Power')
plt.title('Customer 1, 5/07/2012')
# Out:
# Text(0.5, 1.0, 'Customer 1, 5/07/2012')
